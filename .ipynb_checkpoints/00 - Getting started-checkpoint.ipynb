# %% [markdown]
# # Getting started
#
# Topics:
# 1. How to print
# 2. How to assign variables
# 3. How to comment
# 4. Syntax for basic math
#
# [Link to the course](https://juliaacademy.com/p/intro-to-julia)
#
# [Link to the notebook](https://github.com/JuliaAcademy/Introduction-to-Julia)

# %% [markdown]
# ## How to print
#
# In Julia we usually use `println()` to print

# %%
println("I'm excited to learn Julia!")

# %% [markdown]
# ## How to assign variables
#
# All we need is a variable name, value, and an equal's sign!<br>
# Julia will figure out types for us.

# %%
my_answer = 42
typeof(my_answer)

# %%
my_pi = 3.14159
typeof(my_pi)

# %%
😺 = "smiley cat!"
typeof(😺)

# %% [markdown]
# To type a smiley cat, use tab completion to select the emoji name and then tab again

# %%
# \:smi + <tab> --> select with down arrow + <enter> ---> <tab> + <enter> to complete

# %% [markdown]
# After assigning a value to a variable, we can reassign a value of a different type to that variable without any issue.

# %%
😺 = 1

# %%
typeof(😺)

# %% [markdown]
# Note: Julia allows us to write super generic code, and 😺 is an example of this.
#
# This allows us to write code like

# %%
😀 = 0
😞 = -1

# %%
😺 + 😞 == 😀

# %% [markdown]
# ## How to comment

# %%
# You can leave comments on a single line using the pound/hash key

# %%
#=

For multi-line comments, 
use the '#= =#' sequence.

=#

# %% [markdown]
# ## Syntax for basic math
#
# $$
#     f(x) = 2
# $$

# %%
sum = 3 + 7

# %%
difference = 10 - 3

# %%
product = 20 * 5

# %%
quotient = 100 / 10

# %%
power = 10 ^ 2

# %%
modulus = 101 % 2

# %% [markdown]
# ### Exercises
#
# #### 1.1
# Look up [docs](https://docs.julialang.org/en/v1/) for the `convert` function.

# %%
convert(Int64, 3.0)

# %% [markdown]
# #### 1.2
# Assign `365` to a variable named `days`. Convert `days` to a float and assign it to variable `days_float`

# %%
days = 365
days_float = convert(Float64, days)

# %% [markdown]
# `@assert`: Throw an AssertionError `if cond is false`. Preferred syntax for writing assertions. Message text is optionally displayed upon assertion failure.

# %%
@assert iseven(3) "3 is an odd number!"

# %%
@assert isodd(3) "What even are numbers?"

# %% [markdown]
# #### 1.3
# See what happens when you execute
#
# ```julia
# convert(Int64, "1")
#
# parse(Int64, "1")
# ```

# %%
convert(Int64, "1")

# %% [markdown]
# This happens because you cannott `convert` an object of type `String` to an object of type `Int64`

# %%
parse(Int64, "1")
